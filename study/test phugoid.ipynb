# %%
# %run phugoid.py

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
for theta in np.linspace(-1, 3) :
    plot_flight_path(64,16,theta)

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
@interact(theta=[-1, 3, 0.1])
def plot(theta):
    plot_flight_path(64,16,theta)
